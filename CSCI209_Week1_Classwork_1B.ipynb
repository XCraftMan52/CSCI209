# %% [markdown]
# <a href="https://colab.research.google.com/github/XCraftMan52/CSCI209/blob/main/CSCI209_Week1_Classwork_1B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lucas Webber - Winter Break Story
#
# ## Introduction
# My winter break was a time for me to relax, and spend time with the people that I care about.
#
# ## Highlights of My Break
# - Spent time with my family
# - Went on some adventures with my GF
# - Set up and ran my christmas light show
#
# I spent alot of time working on my light show called **Webber Lights**. The Website that I made for the project is [webberlights.com](https://webberlights.com).
#
# Here is a image of my light show to capture what it looks like
#
# ![2025 Show](https://www.webberlights.com/assets/images/2024_Show.jpeg)
#
# ###Things that I have learned over break
# 1. Time is very valuable and I need to use it more wisely
# 2. Rest is very important
